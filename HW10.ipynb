# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

import warnings
warnings.filterwarnings("ignore")

# %%
df = [["Milk", "Onion", "Nutmeg", "Kidney Beans", "Eggs", "Yogurt"], 
      ["Dill", "Onion", "Nutmeg", "Kidney Beans", "Eggs", "Yogurt"], 
      ["Milk", "Apple", "Kidney Beans", "Yogurt"], 
      ["Milk", "Unicorn", "Corn", "Kidney Beans", "Yogurt"], 
      ["Corn", "Onion", "Onion", "Kidney Beans", "Ice cream", "Eggs"]]

# %%
te = TransactionEncoder()
nw_df = te.fit(df).transform(df)
nw_df
# Out:
# array([[False, False, False,  True, False,  True,  True,  True,  True,
#         False,  True],
#        [False, False,  True,  True, False,  True, False,  True,  True,
#         False,  True],
#        [ True, False, False, False, False,  True,  True, False, False,
#         False,  True],
#        [False,  True, False, False, False,  True,  True, False, False,
#          True,  True],
#        [False,  True, False,  True,  True,  True, False, False,  True,
#         False, False]])

# %%
df = pd.DataFrame(nw_df, columns=te.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False  False      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False    True
# 3     True    True
# 4    False   False

# %%
apriori(df, min_support=0.6)
# Out:
#     support    itemsets
# 0       0.6         (3)
# 1       1.0         (5)
# 2       0.6         (6)
# 3       0.6         (8)
# 4       0.8        (10)
# 5       0.6      (3, 5)
# 6       0.6      (8, 3)
# 7       0.6      (5, 6)
# 8       0.6      (8, 5)
# 9       0.8     (10, 5)
# 10      0.6     (10, 6)
# 11      0.6   (8, 3, 5)
# 12      0.6  (10, 5, 6)

# %%
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                      itemsets  length
# 0       0.6                        (Eggs)       1
# 1       1.0                (Kidney Beans)       1
# 2       0.6                        (Milk)       1
# 3       0.6                       (Onion)       1
# 4       0.8                      (Yogurt)       1
# 5       0.6          (Eggs, Kidney Beans)       2
# 6       0.6                 (Eggs, Onion)       2
# 7       0.6          (Milk, Kidney Beans)       2
# 8       0.6         (Onion, Kidney Beans)       2
# 9       0.8        (Kidney Beans, Yogurt)       2
# 10      0.6                (Milk, Yogurt)       2
# 11      0.6   (Eggs, Onion, Kidney Beans)       3
# 12      0.6  (Kidney Beans, Yogurt, Milk)       3

# %%
frequent_itemsets[(frequent_itemsets['length'] == 2) & (frequent_itemsets['support'] >= 0.8)]
# Out:
#    support                itemsets  length
# 9      0.8  (Kidney Beans, Yogurt)       2

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules
# Out:
#                antecedents             consequents  antecedent support  \
# 0                   (Eggs)          (Kidney Beans)                 0.6
# 1                   (Eggs)                 (Onion)                 0.6
# 2                  (Onion)                  (Eggs)                 0.6
# 3                   (Milk)          (Kidney Beans)                 0.6
# 4                  (Onion)          (Kidney Beans)                 0.6
# 5           (Kidney Beans)                (Yogurt)                 1.0
# 6                 (Yogurt)          (Kidney Beans)                 0.8
# 7                   (Milk)                (Yogurt)                 0.6
# 8                 (Yogurt)                  (Milk)                 0.8
# 9            (Eggs, Onion)          (Kidney Beans)                 0.6
# 10    (Eggs, Kidney Beans)                 (Onion)                 0.6
# 11   (Onion, Kidney Beans)                  (Eggs)                 0.6
# 12                  (Eggs)   (Onion, Kidney Beans)                 0.6
# 13                 (Onion)    (Eggs, Kidney Beans)                 0.6
# 14  (Yogurt, Kidney Beans)                  (Milk)                 0.8
# 15    (Milk, Kidney Beans)                (Yogurt)                 0.6
# 16          (Milk, Yogurt)          (Kidney Beans)                 0.6
# 17                (Yogurt)    (Milk, Kidney Beans)                 0.8
# 18                  (Milk)  (Yogurt, Kidney Beans)                 0.6
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  1.0      0.6        1.00  1.000000      0.00         inf
# 1                  0.6      0.6        1.00  1.666667      0.24         inf
# 2                  0.6      0.6        1.00  1.666667      0.24         inf
# 3                  1.0      0.6        1.00  1.000000      0.00         inf
# 4                  1.0      0.6        1.00  1.000000      0.00         inf
# 5                  0.8      0.8        0.80  1.000000      0.00         1.0
# 6                  1.0      0.8        1.00  1.000000      0.00         inf
# 7                  0.8      0.6        1.00  1.250000      0.12         inf
# 8                  0.6      0.6        0.75  1.250000      0.12         1.6
# 9                  1.0      0.6        1.00  1.000000      0.00         inf
# 10                 0.6      0.6        1.00  1.666667      0.24         inf
# 11                 0.6      0.6        1.00  1.666667      0.24         inf
# 12                 0.6      0.6        1.00  1.666667      0.24         inf
# 13                 0.6      0.6        1.00  1.666667      0.24         inf
# 14                 0.6      0.6        0.75  1.250000      0.12         1.6
# 15                 0.8      0.6        1.00  1.250000      0.12         inf
# 16                 1.0      0.6        1.00  1.000000      0.00         inf
# 17                 0.6      0.6        0.75  1.250000      0.12         1.6
# 18                 0.8      0.6        1.00  1.250000      0.12         inf
#
#     zhangs_metric  antecedent_len
# 0             0.0               1
# 1             1.0               1
# 2             1.0               1
# 3             0.0               1
# 4             0.0               1
# 5             0.0               1
# 6             0.0               1
# 7             0.5               1
# 8             1.0               1
# 9             0.0               2
# 10            1.0               2
# 11            1.0               2
# 12            1.0               1
# 13            1.0               1
# 14            1.0               2
# 15            0.5               2
# 16            0.0               2
# 17            1.0               1
# 18            0.5               1

# %%
rules[(rules['antecedent_len'] >= 2) & (rules['confidence'] > 0.75) & (rules['lift'] > 1.2)]
# Out:
#               antecedents consequents  antecedent support  consequent support  \
# 10   (Eggs, Kidney Beans)     (Onion)                 0.6                 0.6
# 11  (Onion, Kidney Beans)      (Eggs)                 0.6                 0.6
# 15   (Milk, Kidney Beans)    (Yogurt)                 0.6                 0.8
#
#     support  confidence      lift  leverage  conviction  zhangs_metric  \
# 10      0.6         1.0  1.666667      0.24         inf            1.0
# 11      0.6         1.0  1.666667      0.24         inf            1.0
# 15      0.6         1.0  1.250000      0.12         inf            0.5
#
#     antecedent_len
# 10               2
# 11               2
# 15               2

# %%
rules[rules['antecedents'] == {'Eggs', 'Kidney Beans'}]
# Out:
#              antecedents consequents  antecedent support  consequent support  \
# 10  (Eggs, Kidney Beans)     (Onion)                 0.6                 0.6
#
#     support  confidence      lift  leverage  conviction  zhangs_metric  \
# 10      0.6         1.0  1.666667      0.24         inf            1.0
#
#     antecedent_len
# 10               2

# %%
trans = [["Shirt", "Shoes", "Pants", "Hat", "Sunglasses", "Watch"], 
         ["Shirt", "Shoes", "Hat", "Sunglasses", "Watch"],
         ["Shirt", "Pants", "Belt"], 
         ["Shoes", "Hat", "Sunglasses", "Watch"],
         ["Shirt", "Shoes", "Pants", "Belt", "Sunglasses"]
        ]

# %%
te = TransactionEncoder()
nw_df = te.fit(trans).transform(trans)

df = pd.DataFrame(nw_df, columns=te.columns_)
df
# Out:
#     Belt    Hat  Pants  Shirt  Shoes  Sunglasses  Watch
# 0  False   True   True   True   True        True   True
# 1  False   True  False   True   True        True   True
# 2   True  False   True   True  False       False  False
# 3  False   True  False  False   True        True   True
# 4   True  False   True   True   True        True  False

# %%
frequent_itemsets = apriori(df, min_support=0.65, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#    support             itemsets  length
# 0      0.8              (Shirt)       1
# 1      0.8              (Shoes)       1
# 2      0.8         (Sunglasses)       1
# 3      0.8  (Shoes, Sunglasses)       2

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.75)

# %%
rules
# Out:
#     antecedents   consequents  antecedent support  consequent support  \
# 0       (Shoes)  (Sunglasses)                 0.8                 0.8
# 1  (Sunglasses)       (Shoes)                 0.8                 0.8
#
#    support  confidence  lift  leverage  conviction  zhangs_metric
# 0      0.8         1.0  1.25      0.16         inf            1.0
# 1      0.8         1.0  1.25      0.16         inf            1.0
